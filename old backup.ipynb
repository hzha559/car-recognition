# %%
            elif "酷威" in filename:
                index=48
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#道奇SUV
            elif "菱悦" in filename or "东南A5翼舞" in filename or "东南DX" in filename:
                index=49
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#东南轿车
                '''#占有率低
            elif "DS 5" in filename or "DS 4S" in filename:
                index=51
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#长安标致雪铁龙轿车
            elif "DS 6" in filename or "DS 7" in filename:
                index=52
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#长安标致雪铁龙SUV
                '''
####################################f
            elif "YARiS L" in filename or "雷凌" in filename or "威驰" in filename or "卡罗拉" in filename or "皇冠" in filename or "锐志" in filename or "凯美瑞" in filename or "亚洲龙" in filename:
                index=53
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#丰田轿车
            elif "丰田C-HR" in filename or "汉兰达" in filename or "奕泽IZOA" in filename or "RAV4荣放" in filename or "普拉多" in filename or "兰德酷路泽" in filename or "FJ 酷路泽" in filename:
                index=54
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#丰田SUV
            elif "埃尔法" in filename or "威尔法" in filename or "普瑞维亚" in filename:
                index=55
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#丰田MPV
            elif "HIACE" in filename or "柯斯达" in filename:
                index=56
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#丰田客车
            elif "福克斯" in filename or "福睿斯" in filename or "金牛座" in filename or "蒙迪欧" in filename or "嘉年华" in filename:
                index=57
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福特轿车
            elif "翼搏" in filename or "锐际" in filename or "翼虎" in filename or "领界" in filename or "撼路者" in filename or "探险者" in filename or "Ranger" in filename:
                index=58
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福特SUV
            elif "Mustang" in filename:
                index=59
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福特跑车
            elif "全顺" in filename or "途睿欧" in filename:
                index=60
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福特MPV
            elif "伽途GT" in filename or "风景V5" in filename or "蒙派克E" in filename or "风景G5" in filename or "伽途i" in filename or "萨瓦纳" in filename:
                index=61
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福田MPV
            elif "风景G7" in filename or "风景G9" in filename or "图雅诺" in filename or "蒙派克S" in filename or "图雅诺" in filename:
                index=62
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福田厢式车
            elif "祥菱V" in filename or "拓陆者" in filename:
                index=63
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#福田皮卡
            elif "法拉利" in filename:
                index=64
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#法拉利跑车
############################g
            elif "传祺GA" in filename or '广汽丰田iA5' in filename or '祺智EV' in filename or 'Aion S(埃安S)' in filename:
                index=65
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#广汽传祺轿车
            elif "传祺GS" in filename or '广汽ix4' in filename or '祺智PHEV' in filename or '传祺GE3' in filename or 'Aion LX(埃安LX)' in filename:
                index=66
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#广汽传祺SUV
            elif "传祺GM" in filename:
                index=67
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#广汽传祺MPV
            elif "观致3" in filename or "观致5" in filename:
                index=68
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#观致汽车
            elif "YUKON" in filename or "SAVANA" in filename or "SIERRA" in filename:
                index=69
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#GMC汽车
            elif "哈弗H" in filename or "哈弗F" in filename:
                index=71
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#长城SUV

            elif "红旗" in filename:
                index=73
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#红旗
            elif "海马爱尚EV" in filename or "海马E3" in filename or "海马M3" in filename or "福美来" in filename:
                index=74
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#海马轿车
            elif "海马8S" in filename or "海马S" in filename:
                index=75
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#海马SUV
            elif "海格H" in filename:
                index=76
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#金龙厢式车
            elif "金刚" in filename or "缤瑞" in filename or "帝豪" in filename or ("远景" in filename and '远景X' not in filename) or "博瑞" in filename:
                index=77
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#吉利轿车
            elif ("越" in filename and '吉利' in filename) or '嘉际' in filename or '吉利icon'in filename:
                index=78
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#吉利SUV
            elif "Jeep" in filename:
                index=79
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#吉普SUV
            elif "捷达" in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#捷达汽车
            elif "海狮" in filename or "金杯T" in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#金杯厢式车或皮卡
            elif '捷豹X' in filename or '捷豹F'in filename or '捷豹I-PACE'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#捷豹汽车
            elif "捷途" in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#捷途suv
            elif "江铃" in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#江铃汽车
            elif "金龙" in filename or '金旅'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#金龙汽车
            elif "凯迪拉克ATS-L" in filename or '凯迪拉克CT'in filename or '凯迪拉克XTS'in filename or '凯迪拉克SLS'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#凯迪拉克轿车
            elif "凯迪拉克XT" in filename or '凯雷德' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#凯迪拉克suv
            elif "克莱斯勒300C" in filename or '大捷龙'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#克莱斯勒
            elif "雷克萨斯CT" in filename or '雷克萨斯IS'in filename or '雷克萨斯ES'in filename or '雷克萨斯LS'in filename or '雷克萨斯LC'in filename or '雷克萨斯RC'in filename or '雷克萨斯GS'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雷克萨斯轿车
            elif "雷克萨斯UX" in filename or '雷克萨斯NX'in filename or '雷克萨斯RX'in filename or '雷克萨斯LX'in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雷克萨斯suv
            elif '路虎' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#路虎suv
            elif '林肯' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#林肯
            elif '领克' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#领克
            elif '昌河铃木' in filename or '雨燕' in filename or '天语 SX4' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#领克
            elif '东风雷诺' in filename or 'Espace' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雷诺
            elif '东风雷诺' in filename or 'Espace' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雷诺
            elif 'Urus' in filename or 'Hurac' in filename or 'Aventador' in filename or 'Gallardo' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#兰博基尼
            elif '幻影' in filename or '古思特' in filename or '库里南' in filename or '魅影' in filename or '曜影' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#劳斯莱斯
            elif '猎豹CS' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#猎豹
            elif '陆风X' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#陆风
            elif '马自达3' in filename or '阿特兹' in filename or '睿翼' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#马自达轿车
            elif '马自达CX' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#马自达suv
            elif '名爵6' in filename or '名爵3' in filename or '名爵7' in filename or '锐行' in filename or '名爵ZS' in filename or '名爵HS' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#名爵
            elif 'MINI O' in filename or 'MINI CLUBMAN' in filename or 'MINI COUNTRYMAN' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#迷你
            elif 'Ghibli' in filename or '总裁' in filename or 'Levante' in filename or 'GranTurismo' in filename or 'GranCabrio' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#玛莎拉蒂
            elif '大7 SUV' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#纳智捷suv
            elif '艾瑞泽' in filename or '旗云' in filename or '风云' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#奇瑞轿车
            elif '瑞虎' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#奇瑞suv
            elif 'KX CROSS' in filename or '起亚K' in filename or '焕驰' in filename or '福瑞迪' in filename or '凯绅' in filename or '秀尔' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#起亚轿车
            elif '起亚KX' in filename or '智跑' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#起亚suv
            elif '启辰D60' in filename or '启辰e30' in filename or '启辰T60' in filename or '启辰T70' in filename or '启辰T90' in filename or '启辰M50V' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#启辰suv
            elif '骊威' in filename or '骐达TIIDA' in filename or '轩逸' in filename or '阳光' in filename or '蓝鸟' in filename or '天籁' in filename or '西玛' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#日产轿车
            elif '劲客' in filename or '逍客' in filename or '途达' in filename or '奇骏' in filename or '楼兰' in filename or '天籁' in filename or '西玛' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#日产suv
            elif '日产NV200' in filename or '纳瓦拉' in filename or '日产D22' in filename or '日产ZN厢式车' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#日产厢式车
            elif '荣威3' in filename or '荣威i' in filename or '荣威RX' in filename or '荣威MARVEL X' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#荣威
            elif ('斯柯达' in filename and '锐' in filename) or '昕动' in filename or '速派' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#斯柯达轿车
            elif '斯柯达' in filename and '克' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#斯柯达suv
            elif '蓝瑟' in filename or '翼神' in filename or '广汽三菱' in filename or '帕杰罗(进口)' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#三菱
            elif '上汽MAXUS D' in filename or '上汽MAXUS T' in filename or '上汽MAXUS G' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#上汽大通
            elif '力狮' in filename or '斯巴鲁XV' in filename or '森林人' in filename or '斯巴鲁BRZ' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#斯巴鲁
            elif 'smart fortwo' in filename or 'smart forfour' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#smart
            elif '华晨鑫源' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#华晨鑫源
            elif 'SWM斯威汽车' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#SWM斯威汽车
            elif 'Model 3' in filename or 'Model S' in filename or 'Model X' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#特斯拉
            elif '沃尔沃S' in filename or ('沃尔沃XC' in filename and '沃尔沃亚太' in filename) or '沃尔沃V40' in filename or '沃尔沃V60' in filename or '沃尔沃V90' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#沃尔沃
            elif (('五菱宏光' in filename and '五菱宏光S3' not in filename) or '五菱荣光' in filename and '五菱之光' in filename) and '卡' not in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#五菱厢式车
            elif (('五菱宏光' in filename and '五菱宏光S3' not in filename) or '五菱荣光' in filename and '五菱之光' in filename) and '卡' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#五菱皮卡
            elif 'WEY' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#WEY汽车
            elif ('江西五十铃' in filename and '瑞迈EV' not in filename) or '庆铃汽车' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#五十铃
            elif '蔚来ES' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#蔚来汽车
            elif '瑞纳' in filename or '悦纳' in filename or '北京现代i30' in filename or '悦动' in filename or '菲斯塔' in filename or '领动' in filename or '伊兰特EV' in filename or '逸行' in filename or '名图' in filename or '索纳塔九' in filename or '索纳塔插电混动' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#现代轿车
            elif '昂希诺' in filename or '北京现代ix' in filename or '途胜' in filename or '胜达' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#现代suv
            elif '康恩迪' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#现代客车
            elif ('科' in filename and not '科帕奇' in filename and '上汽通用雪佛兰' in filename) or '迈锐宝' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雪佛兰轿车
            elif '畅巡' in filename or '沃兰多' in filename or '探界者' in filename or '创界' in filename or '创酷' in filename:
                index=80
                self.data_ids.append(index)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#雪佛兰suv
           }
#if  in filename or  in filename or  in filename or "" in filename or in filename: #and a[0]<300:
'''index=0
                self.data_ids.append(0)
                self.data_filenames.append(filename)
                a[index]=a[index]+1#奥迪轿车
'''
#print(dictionary)
